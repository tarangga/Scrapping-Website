# %% [markdown]
# <a href="https://colab.research.google.com/github/tarangga/Scrapping-Website/blob/main/COVID_NTB_Crawler.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import requests
import bs4
import lxml.etree as xml

# %%
html = """

<!DOCTYPE html>
<html lang="en">

<head>
    <!-- Global site tag (gtag.js) - Google Analytics -->
    <script async src="https://www.googletagmanager.com/gtag/js?id=UA-163333484-1"></script>
    <script>
        window.dataLayer = window.dataLayer || [];
        function gtag(){dataLayer.push(arguments);}
        gtag('js', new Date());

        gtag('config', 'UA-163333484-1');
    </script>
    <!-- BEGIN SHAREAHOLIC CODE -->
    <link rel="preload" href="https://cdn.shareaholic.net/assets/pub/shareaholic.js" as="script" />
    <meta name="shareaholic:site_id" content="f0e8a6de2770421d715b9e8662bc7b74" />
    <script data-cfasync="false" async src="https://cdn.shareaholic.net/assets/pub/shareaholic.js"></script>
    <!-- END SHAREAHOLIC CODE -->

    <meta charset="utf-8">
    <meta http-equiv="X-UA-Compatible" content="IE=edge">
    <meta name="viewport" content="width=device-width, initial-scale=1">
    <meta name="description" content="">
    <meta name="author" content="">
    <link rel="icon" type="image/png" sizes="16x16" href="https://corona.ntbprov.go.id/backend/assets/images/favicon.png">
    <title>COVID-19 NTB</title>
    <!-- Bootstrap Core CSS -->
<link href="/frontend/assets/node_modules/bootstrap/css/bootstrap.min.css" rel="stylesheet">
<!-- This is for the animation CSS -->
<link href="/frontend/assets/node_modules/aos/dist/aos.css" rel="stylesheet">
<link href="/frontend/assets/node_modules/perfect-scrollbar/dist/css/perfect-scrollbar.min.css" rel="stylesheet">
<!-- This css we made it from our predefine componenet
we just copy that css and paste here you can also do that -->
<link href="/frontend/css/demo.css" rel="stylesheet">
<!-- Common style CSS -->
<link href="/frontend/css/style.css" rel="stylesheet">
<link href="/frontend/css/yourstyle.css" rel="stylesheet">
<link href="/frontend/css/features/features1-10.css" rel="stylesheet">
<link href="/frontend/css/features/features11-20.css" rel="stylesheet">
<link href="/frontend/css/features/features21-30.css" rel="stylesheet">
<link href="/frontend/css/features/features31-40.css" rel="stylesheet">
<link href="/frontend/css/footers/footers.css" rel="stylesheet">
<link href="/frontend/assets/node_modules/owl.carousel/dist/assets/owl.theme.green.css" rel="stylesheet">
<link href="/frontend/css/testimonial/testimonial1-10.css" rel="stylesheet">
<link rel="stylesheet" href="/backend/css/icons/material-design-iconic-font/css/materialdesignicons.min.css">
<script src='https://api.mapbox.com/mapbox-gl-js/v1.8.0/mapbox-gl.js'></script>
<link href='https://api.mapbox.com/mapbox-gl-js/v1.8.0/mapbox-gl.css' rel='stylesheet' />
<link href="/backend/assets/plugins/datatables/media/css/dataTables.bootstrap4.css" rel="stylesheet">


<style>
    /* body {
        font-family: 'Open Sans', sans-serif;
        font-size: 10pt;
    } */

    .topbar {
        background: white;
    }

    canvas {
        display: block;
        vertical-align: bottom;
    }


    /* h1,
    h2,
    h3,
    h4,
    h5,
    h6 {
        font-family: 'Open Sans', sans-serif;
        font-weight: 800;
    } */

    .sidebar-nav>ul>li>a.active {
        border-radius: unset;
    }

    .card-no-border .card {
        border-radius: unset;
    }

    .layer {
        background-color: rgba(255, 255, 255, 0.94);
        position: absolute;
        top: 0;
        left: 0;
        width: 100%;
        height: 100%;
    }

    .header17 .h17-nav {
        background: white;
    }
</style>
</head>

<body class="">
    <div id="main-wrapper">
        <div class="topbar">
            <div class="header17">
                <div class="container">
                    <nav class="h17-nav navbar">
                        <div class="">
                            <a class="navbar-brand" href="/"><img src="https://corona.ntbprov.go.id/backend/logo.png"
                                    style="height: 85px" alt="wrapkit" /></a>
                        </div>
                        <div class="ml-auto align-self-center">
                            <ul class="list-inline h17nav-bar">
                                <li><a class="nav-link tgl-cl" href="javascript:void(0)"><img
                                            src="/frontend/images/toggle-menu.png" alt="wrapkit" /></a></li>
                            </ul>
                        </div>
                    </nav>
                </div>
            </div>
        </div>
        <div class="h17-main-nav animated fadeInDown justify-content-center" data-aos="fade-up">
            <div class="h-17navbar align-self-center">
                <a href="javascript:void(0)" class="close-icons tgl-cl"><i class="ti-close"></i></a>
                <ul class="nav-menu">
                    <li><a href="/">Beranda</a></li>
                    <li><a class="btn btn-info-gradiant" target="_blank" href="/api/data">Get API</a></li>
                </ul>
            </div>
        </div>
        <div class="page-wrapper">
            <div class="container-fluid">
                <div class="container" style="margin-top: 130px;">
    <div class="row">
        <div class="col-md-7">
            <h2 class="title" style="font-weight: 900">History Data<span class="text-info-gradiant">.</span></h2>
            
        </div>
    </div>
    <br>
    <div class="row">
        <div class="col-md-12">
            <div class="card">
                <div class="table-responsive">
                    <table class="table table-bordered" id="myTable">
                        <thead>
                            <tr>
                                <th style="width: 5%">#</th>
                                <th>Tanggal</th>
                                <th style="width: 10%"></th>
                            </tr>
                        </thead>
                        <tbody>
                                                        <tr>
                                <td>1</td>
                                <td>
                                    17 Oktober 2020 21:51
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/d46389e0-107f-11eb-bb28-a537ea47fb26/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>2</td>
                                <td>
                                    16 Oktober 2020 21:59
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/da6ea970-0fb7-11eb-bc33-bfaf84b36c23/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>3</td>
                                <td>
                                    15 Oktober 2020 21:07
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/64fb77c0-0ee7-11eb-876f-a3d6dd1ba634/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>4</td>
                                <td>
                                    14 Oktober 2020 21:22
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/3e6df270-0e20-11eb-a62b-a3e23b9ee08f/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>5</td>
                                <td>
                                    13 Oktober 2020 22:41
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/30238460-0d62-11eb-922b-d1deda26f2fb/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>6</td>
                                <td>
                                    12 Oktober 2020 21:02
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/20899f90-0c8b-11eb-a4e8-35fe0c12d0c1/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>7</td>
                                <td>
                                    11 Oktober 2020 20:07
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/49a39fd0-0bba-11eb-91cb-a3c04ff343a7/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>8</td>
                                <td>
                                    10 Oktober 2020 21:43
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/929877a0-0afe-11eb-bde8-9d12f1a2c430/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>9</td>
                                <td>
                                    09 Oktober 2020 23:07
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/2d5b5510-0a41-11eb-8725-bde680df9daa/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>10</td>
                                <td>
                                    08 Oktober 2020 21:49
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/47222f80-6830-11ea-8c4f-df3c256ae2f2/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>218</td>
                                <td>
                                    16 Maret 2020 14:09
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/a969ccb0-674c-11ea-8ed3-0d1437d52a64/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                        <tr>
                                <td>219</td>
                                <td>
                                    15 Maret 2020 13:40
                                </td>
                                <td style="text-align: center;">
                                    <a href="https://corona.ntbprov.go.id/data/6e46c310-667f-11ea-b308-a774473c876b/show" class="btn btn-sm btn-info"><span
                                            class="fa fa-eye"></span> Lihat Data</a>
                                </td>
                            </tr>
                                                    </tbody>
                    </table>
                </div>
            </div>
        </div>
    </div>
</div>
            </div>
        </div>
    </div>
    <div class="footer1 font-14" style="margin-top: 30px;">
        <div class="f1-bottom-bar">
            <div class="container">
                <div class="d-flex">
                    <div class="m-t-10 m-b-10">© 2020 Developed by <a
                            href="https://diskominfotik.ntbprov.go.id/" style="color: inherit">DISKOMINFOTIK NTB</a>.
                    </div>
                    
                </div>
            </div>
        </div>
    </div>
    <!-- ============================================================== -->
<!-- All Jquery -->
<!-- ============================================================== -->
<script src="/frontend/assets/node_modules/jquery/dist/jquery.min.js"></script>
<!-- Bootstrap popper Core JavaScript -->
<script src="/frontend/assets/node_modules/popper/dist/popper.min.js"></script>
<script src="/frontend/assets/node_modules/bootstrap/js/bootstrap.min.js"></script>
<!-- This is for the animation -->
<script src="/frontend/assets/node_modules/aos/dist/aos.js"></script>
<!--Custom JavaScript -->
<script src="/frontend/js/custom.min.js"></script>
<!-- ============================================================== -->
<!-- This page plugins -->
<!-- ============================================================== -->
<script src="/frontend/js/type.js"></script>
<script src="/frontend/assets/node_modules/perfect-scrollbar/dist/js/perfect-scrollbar.jquery.min.js"></script>
<script src="/frontend/js/portfolio.js"></script>
<script>
    $('.tgl-cl').on('click', function() {
        $('body .h17-main-nav').toggleClass("show");
    });
</script>
<script src="/backend/assets/plugins/echarts/echarts-all.js"></script>


<script src="/backend/assets/plugins/raphael/raphael-min.js"></script>
<script src="/backend/assets/plugins/morrisjs/morris.js"></script>
<script src="/frontend/assets/node_modules/owl.carousel/dist/owl.carousel.min.js"></script>
<script src="/frontend/js/testimonial/testimonial.js"></script>
<script src="/backend/assets/plugins/datatables/datatables.min.js"></script>
<script>
    $('#myTable').DataTable({
        "language": {
                    "url": "https://cdn.datatables.net/plug-ins/1.10.20/i18n/Indonesian.json"
                },
        "pageLength": 25
    });
</script>
<script src="/frontend/assets/node_modules/owl.carousel/dist/owl.carousel.min.js"></script>
<script>
    // this is for the feature no:35
    $('.feature-35-owl').owlCarousel({
        loop: true,
        margin: 30,
        responsiveClass: true,
        responsive: {
            0: {
                items: 1,
                nav: false
            },
            1000: {
                items: 2,
                nav: false
            },
            1650: {
                items: 3,
                nav: false,
                loop: false
            }
        }
    })
</script>
<!-- ============================================================== -->
<!-- This page plugins -->
<!-- ============================================================== -->
<script type="text/javascript">
    $('.pre-scroll').perfectScrollbar();
</script>
<!-- ============================================================== -->
<!-- This page plugins -->
<!-- ============================================================== -->
<script src="/frontend/js/jquery.waypoints.min.js"></script>
<script src="/frontend/js/jquery.counterup.min.js"></script>
<script type="text/javascript">
    // This is for counter
    $('.counter').counterUp({
        delay: 10
    });
</script>
</body>

</html>
"""

# %%
web_page = bs4.BeautifulSoup(html, "html.parser")
table = web_page.find_all(name='table', attrs = {'class', 'table table-bordered dataTable no-footer'})
tbody = web_page.table.tbody

link = []
index = []
for i in range(74):
  index.append(tbody.find_all(name='tr')[i].find_all(name='td')[1].text.strip())
  link.append(tbody.find_all(name='tr')[i].a.attrs['href'])

# %%
import pandas as pd

link_covid = pd.DataFrame(link,columns=['link'], index=index)
link_covid
# Out:
#                                                                     link
# 17 Oktober 2020 21:51  https://corona.ntbprov.go.id/data/d46389e0-107...
# 16 Oktober 2020 21:59  https://corona.ntbprov.go.id/data/da6ea970-0fb...
# 15 Oktober 2020 21:07  https://corona.ntbprov.go.id/data/64fb77c0-0ee...
# 14 Oktober 2020 21:22  https://corona.ntbprov.go.id/data/3e6df270-0e2...
# 13 Oktober 2020 22:41  https://corona.ntbprov.go.id/data/30238460-0d6...
# ...                                                                  ...
# 10 Agustus 2020 21:00  https://corona.ntbprov.go.id/data/770a2920-db5...
# 09 Agustus 2020 20:28  https://corona.ntbprov.go.id/data/d2fc3100-da3...
# 08 Agustus 2020 21:03  https://corona.ntbprov.go.id/data/84dc90b0-d97...
# 07 Agustus 2020 21:00  https://corona.ntbprov.go.id/data/f6367330-d8a...
# 06 Agustus 2020 21:52  https://corona.ntbprov.go.id/data/09f45220-d7e...
#
# [74 rows x 1 columns]

# %%
def get_data(url):
  web_page = bs4.BeautifulSoup(requests.get(url, {}).text, "html.parser")
  d = web_page.table.find_all(name='tr')[-1].find_all(name='td')
  res = []

  for v in d[1:]:
    res.append(v.text.strip())

  return res

# %%
data = pd.read_csv('/content/COVID NTB - Data (3).csv', index_col='Tanggal')
data.head()
id_data = data.index
id_link = link_covid.index

# %%
res = []

for i in range(74):
  res.append(get_data(link_covid.link[i]))

# %%
data_covid = pd.DataFrame(res, columns=data.columns)
data_covid['index'] = index

# %%
data_covid.set_index('index').to_csv('/content/COVID NTB - Data.csv')

# %%
data_covid.loc[range(0, 74, 7), :].to_csv('/content/COVID NTB - Data per Minggu.csv', index='index')

# %%
data_minggu = data_covid.loc[range(0, 74, 7), :].set_index('index')[['konfirmasi_isolasi', 'konfirmasi_sembuh', 'konfirmasi_meninggal','konfirmasi_jumlah']]
data_minggu = data_minggu.reset_index().drop(columns=['index'])
print(data_minggu.head())

for col in data_minggu.columns:
  data_minggu[col] = data_minggu[col].astype(int)

# %%
pertumbuhan = data_minggu[0:-1].reset_index() - data_minggu[1:].reset_index()

# %%
pertumbuhan.sum()/pertumbuhan.shape[0]
# Out:
# index                    -1.0
# konfirmasi_isolasi      -26.5
# konfirmasi_sembuh       156.8
# konfirmasi_meninggal      8.1
# konfirmasi_jumlah       138.4
# dtype: float64
